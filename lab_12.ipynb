# %% [markdown]
# # Lab 12
#
# _[General notebook information](https://computing-in-context.afeld.me/notebooks.html)_

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "plotly_mimetype"

fig = px.scatter(x=[1, 2, 3], y=[1, 4, 9])

fig.show()

# %% [markdown]
# ## Setup
#
# [Install](https://computing-in-context.afeld.me/notebooks.html#installing-packages) [`lxml`](https://lxml.de/) and [`requests`](https://requests.readthedocs.io/) packages.

# %% [markdown]
# ## Scraping
#
# Common tools:
#
# - [Beautiful Soup package](https://realpython.com/beautiful-soup-web-scraper-python/)
# - [pandas' `read_html()`](https://pandas.pydata.org/docs/user_guide/io.html#html)

# %% [markdown]
# Pull [Wikipedia's list of countries by area](https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area#Countries_and_dependencies_by_area) into a DataFrame using `read_html()`.

# %%
import pandas as pd

df = pd.read_html(
    "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area#Countries_and_dependencies_by_area"
)
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_html(
#       3     "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area#Countries_and_dependencies_by_area"
#       4 )
#       5 df.head()
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)
#     979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)
#     247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\Users\adith\anaconda3\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\Users\adith\anaconda3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import requests

url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area#Countries_and_dependencies_by_area"
response = requests.get(url)
response.text
# Out:
# 'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also T400119.\n'

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
html = response.text
html
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of countries and dependencies by area - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"9e184b76-3e52-401a-ae9e-49c5b7733cca","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_and_dependencies_by_area","wgTitle":"List of countries and dependencies by area","wgCurRevisionId":1322596748,"wgRevisionId":1322596748,"wgArticleId":3989609,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 French-language sources (fr)","CS1: long volume value","CS1 Japanese-language sources (ja)","Webarchive template wayback links","Articles with Italian-language sources (it)","Articles with short description","Short description is different from Wikidata","Wikipedia pages semi-protected against vandalism","Use dmy dates from January 2022","Water by country","Lists by area","Lists of countries by geography","Geography-related lists","International rankings"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_countries_and_dependencies_by_area","wgRelevantArticleId":3989609,"wgTempUserName":null,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgConfirmEditCaptchaNeededForGenericEdit":false,"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":80000,"wgMetricsPlatformUserExperiments":{"active_experiments":[],"overrides":[],"enrolled":[],"assigned":[],"subject_ids":[],"sampling_units":[]},"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q260023","wgCheckUserClientHintsHeadersJsApi":["brands","architecture","bitness","fullVersionList","mobile", ...

# %%
df = pd.read_html(html)
df
# Out:
# C:\Users\adith\AppData\Local\Temp\ipykernel_27088\1109285248.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(html)
# [                                                0
#  0  Countries of the world by area (legend in km2),
#      Unnamed: 0                     Country / dependency  \
#  0            –                                    Earth
#  1            1                                   Russia
#  2            –                               Antarctica
#  3            2                                   Canada
#  4      3/4 [e]                                    China
#  ..         ...                                      ...
#  257          –  Ashmore and Cartier Islands (Australia)
#  258          –            Coral Sea Islands (Australia)
#  259          –               Spratly Islands (disputed)
#  260        194                                   Monaco
#  261        195                             Vatican City
#
#              Total in km2 (mi2)         Land in km2 (mi2)  \
#  0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
#  1       17,098,246 (6,601,667)    16,376,870 (6,323,142)
#  2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
#  3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
#  4        9,596,960 (3,705,410)     9,326,410 (3,600,950)
#  ..                         ...                       ...
#  257                  5.0 (1.9)                 5.0 (1.9)
#  258                  3.0 (1.2)                 3.0 (1.2)
#  259                 2.0 (0.77)                2.0 (0.77)
#  260                 2.0 (0.77)                2.0 (0.77)
#  261                0.49 (0.19)               0.49 (0.19)
#
#              Water in km2 (mi2)  % water Unnamed: 6
#  0    361,132,000 (139,434,000)     70.8        NaN
#  1            721,380 (278,530)      4.2        [b]
#  2                            0      0.0        [c]
#  3            891,163 (344,080)      8.9        [d]
#  4            270,550 (104,460)      2.8        [f]
#  ..                         ...      ...        ...
#  257                          0      0.0        [q]
#  258                          0      0.0       [db]
#  259                          0      0.0       [55]
#  260                          0      0.0       [dc]
#  261                          0      0.0       [dd]
#
#  [262 rows x 7 columns],
#        vteLists of countries by geographical rankings  \
#  0                                               Area
#  1  Exclusive economic zone Forest Irrigated land ...
#  2                                          Continent
#  3                                     Extreme points
#  4                                          Perimeter
#  5                                             Others
#  6    List of international rankings Lists by country
#
#      vteLists of countries by geographical rankings.1
#  0  Exclusive economic zone Forest Irrigated land ...
#  1  Exclusive economic zone Forest Irrigated land ...
#  2  Africa Asia Europe North America Oceania South...
#  3  Elevation average Latitude Northernmost Southe...
#  4  Coastline length Land borders Land and maritim...
#  5  Freshwater resources withdrawal Number of isla...
#  6    List of international rankings Lists by country  ,
#                                                     0  \
#  0  Exclusive economic zone Forest Irrigated land ...
#  1                                          Continent
#
#                                                     1
#  0  Exclusive economic zone Forest Irrigated land ...
#  1  Africa Asia Europe North America Oceania South...  ]

# %%
df[0]
# Out:
#                                                 0
# 0  Countries of the world by area (legend in km2)

# %%
df = df[1]
df.head()
# Out:
#   Unnamed: 0 Country / dependency         Total in km2 (mi2)  \
# 0          –                Earth  510,072,000 (196,940,000)
# 1          1               Russia     17,098,246 (6,601,667)
# 2          –           Antarctica     14,200,000 (5,480,000)
# 3          2               Canada      9,984,670 (3,855,100)
# 4    3/4 [e]                China      9,596,960 (3,705,410)
#
#           Land in km2 (mi2)         Water in km2 (mi2)  % water Unnamed: 6
# 0  148,940,000 (57,506,000)  361,132,000 (139,434,000)     70.8        NaN
# 1    16,376,870 (6,323,142)          721,380 (278,530)      4.2        [b]
# 2    14,200,000 (5,480,000)                          0      0.0        [c]
# 3     9,093,507 (3,511,021)          891,163 (344,080)      8.9        [d]
# 4     9,326,410 (3,600,950)          270,550 (104,460)      2.8        [f]

# %% [markdown]
# ## Time series
#
# Using [MTA ridership data](https://data.ny.gov/Transportation/MTA-Daily-Ridership-Data-Beginning-2020/vxuj-8kew/about_data), **view the bus ridership over time**. Start with per day, then do per week.

# %%
df = pd.read_csv("MTA_Daily_Ridership_Data__2020_-_2025_20251121.csv")
df.head()
# Out:
#          Date Subways: Total Estimated Ridership  \
# 0  03/01/2020                          2,212,965
# 1  03/02/2020                          5,329,915
# 2  03/03/2020                          5,481,103
# 3  03/04/2020                          5,498,809
# 4  03/05/2020                          5,496,453
#
#   Subways: % of Comparable Pre-Pandemic Day Buses: Total Estimated Ridership  \
# 0                                       97%                          984,908
# 1                                       96%                        2,209,066
# 2                                       98%                        2,228,608
# 3                                       99%                        2,177,165
# 4                                       99%                        2,244,515
#
#   Buses: % of Comparable Pre-Pandemic Day LIRR: Total Estimated Ridership  \
# 0                                     99%                          86,790
# 1                                     99%                         321,569
# 2                                     99%                         319,727
# 3                                     97%                         311,662
# 4                                    100%                         307,597
#
#   LIRR: % of Comparable Pre-Pandemic Day  \
# 0                                   100%
# 1                                   103%
# 2                                   102%
# 3                                    99%
# 4                                    98%
#
#   Metro-North: Total Estimated Ridership  \
# 0                                 55,825
# 1                                180,701
# 2                                190,648
# 3                                192,689
# 4                                194,386
#
#   Metro-North: % of Comparable Pre-Pandemic Day  \
# 0                                           59%
# 1                                           66%
# 2                                           69%
# 3                                           70%
# 4                                           70%
#
#   Access-A-Ride: Total Scheduled Trips  \
# 0                               19,922
# 1                               30,338
# 2                               32,767
# 3                               34,297
# 4                               33,209
#
#   Access-A-Ride: % of Comparable Pre-Pandemic Day  \
# 0                                            113%
# 1                                            102%
# 2                                            110%
# 3                                            115%
# 4                                            112%
#
#   Bridges and Tunnels: Total Traffic  \
# 0                            786,960
# 1                            874,619
# 2                            882,175
# 3                            905,558
# 4                            929,298
#
#   Bridges and Tunnels: % of Comparable Pre-Pandemic Day  \
# 0                                                98%
# 1                                                95%
# 2                                                96%
# 3                                                98%
# 4                                               101%
#
#   Staten Island Railway: Total Estimated Ridership  \
# 0                                            1,636
# 1                                           17,140
# 2                                           17,453
# 3                                           17,136
# 4                                           17,203
#
#   Staten Island Railway: % of Comparable Pre-Pandemic Day
# 0                                                52%
# 1                                               107%
# 2                                               109%
# 3                                               107%
# 4                                               108%

# %%
df = df[["Date", "Buses: Total Estimated Ridership"]]
df.head()
# Out:
#          Date Buses: Total Estimated Ridership
# 0  03/01/2020                          984,908
# 1  03/02/2020                        2,209,066
# 2  03/03/2020                        2,228,608
# 3  03/04/2020                        2,177,165
# 4  03/05/2020                        2,244,515

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 2 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              1776 non-null   object
#  1   Buses: Total Estimated Ridership  1776 non-null   object
# dtypes: object(2)
# memory usage: 27.9+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m/%d/%Y")
df.head()
# Out:
#         Date Buses: Total Estimated Ridership
# 0 2020-03-01                          984,908
# 1 2020-03-02                        2,209,066
# 2 2020-03-03                        2,228,608
# 3 2020-03-04                        2,177,165
# 4 2020-03-05                        2,244,515

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 2 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              1776 non-null   datetime64[ns]
#  1   Buses: Total Estimated Ridership  1776 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 27.9+ KB

# %%
df["Buses: Total Estimated Ridership"] = (
    df["Buses: Total Estimated Ridership"].str.replace(",", "").astype(int)
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 2 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              1776 non-null   datetime64[ns]
#  1   Buses: Total Estimated Ridership  1776 non-null   int32
# dtypes: datetime64[ns](1), int32(1)
# memory usage: 20.9 KB

# %%
import plotly.express as px

fig = px.line(
    df,
    x="Date",
    y="Buses: Total Estimated Ridership",
    title="MTA Daily Bus Ridership (2020-2025)",
)
fig.show()

# %%
weekly = df.resample("W", on="Date").sum().reset_index()
weekly
# Out:
#           Date  Buses: Total Estimated Ridership
# 0   2020-03-01                            984908
# 1   2020-03-08                          13132345
# 2   2020-03-15                          11708729
# 3   2020-03-22                           5678972
# 4   2020-03-29                            300960
# ..         ...                               ...
# 250 2024-12-15                           8522732
# 251 2024-12-22                           8289357
# 252 2024-12-29                           5843020
# 253 2025-01-05                           6414163
# 254 2025-01-12                           4558875
#
# [255 rows x 2 columns]

# %%
fig = px.line(
    weekly,
    x="Date",
    y="Buses: Total Estimated Ridership",
    title="MTA Weekly Bus Ridership (2020-2025)",
)
fig.show()

# %%
monthly = df.resample("M", on="Date").sum().reset_index()
fig = px.line(
    monthly,
    x="Date",
    y="Buses: Total Estimated Ridership",
    title="MTA Monthly Bus Ridership (2020-2025)",
)
fig.show()
# Out:
# C:\Users\adith\AppData\Local\Temp\ipykernel_27088\1208604692.py:1: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.

# %%
yearly = df.resample("Y", on="Date").sum().reset_index()
yearly
# Out:
# C:\Users\adith\AppData\Local\Temp\ipykernel_27088\2518016672.py:1: FutureWarning:
#
# 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#         Date  Buses: Total Estimated Ridership
# 0 2020-12-31                         147387699
# 1 2021-12-31                         381637866
# 2 2022-12-31                         423946824
# 3 2023-12-31                         425539799
# 4 2024-12-31                         408872440
# 5 2025-12-31                           8878078

# %%
fig = px.line(
    yearly,
    x="Date",
    y="Buses: Total Estimated Ridership",
    title="MTA Yearly Bus Ridership (2020-2025)",
)
fig.show()

# %% [markdown]
# ## API
#
# You're going to pick a [World Bank Indicator](https://data.worldbank.org/indicator) and plot that over time. You'll retrieve the data through [the API](https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation).

# %% [markdown]
# ### Tips
#
# - Start simple
# - Use the Python [requests](https://requests.readthedocs.io/) package
# - See [`json_normalize()`](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html)
#
# Retrieve _all_ data for that Indicator through [the API](https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation) — see "Page".

# %%
import requests

url = "https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'page': 1,
#   'pages': 346,
#   'per_page': 50,
#   'total': 17290,
#   'sourceid': '2',
#   'lastupdated': '2025-10-07'},
#  [{'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2024',
#    'value': 769294618,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2023',
#    'value': 750503764,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2022',
#    'value': 731821393,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 713090928,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 694446100,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 675950189,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2018',
#    'value': 657801085,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2017',
#    'value': 640058741,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2016',
#    'value': 623369401,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2015',
#    'value': 607123269,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2014',
#    'value': 590968990,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2013',
#    'value': 575202699,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2012',
#    'value': 559609961,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2011',
#    'value': 544737983,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2010',
#    'value': 530308387,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2009',
#    'value': 516003448,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2008',
#    'value': 502070763,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2007',
#    'value': 488580707,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2006',
#    'value': 475606210,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2005',
#    'value': 463076637,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2004',
#    'value': 450928044,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2003',
#    'value': 439173286,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2002',
#    'value': 427820358,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2001',
#    'value': 416807868,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2000',
#    'value': 406156661,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1999',
#    'value': 395750933,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1998',
#    'value': 385505757,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1997',
#    'value': 375646235,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1996',
#    'value': 366138524,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1995',
#    'value': 356580375,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1994',
#    'value': 347441809,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1993',
#    'value': 338324002,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1992',
#    'value': 329082707,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1991',
#    'value': 320442961,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1990',
#    'value': 311748681,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1989',
#    'value': 302939121,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1988',
#    'value': 294498625,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1987',
#    'value': 286067346,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1986',
#    'value': 277621771,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1985',
#    'value': 269450407,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1984',
#    'value': 261458202,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1983',
#    'value': 253644643,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1982',
#    'value': 245822010,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1981',
#    'value': 238043099,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1980',
#    'value': 230792729,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1979',
#    'value': 223974122,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1978',
#    'value': 217074286,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1977',
#    'value': 210680842,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1976',
#    'value': 204802976,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'SP.POP.TOTL', 'value': 'Population, total'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1975',
#    'value': 198914573,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
df = pd.json_normalize(response.json()[1])
df.head()
# Out:
#   countryiso3code  date      value unit obs_status  decimal indicator.id  \
# 0             AFE  2024  769294618                        0  SP.POP.TOTL
# 1             AFE  2023  750503764                        0  SP.POP.TOTL
# 2             AFE  2022  731821393                        0  SP.POP.TOTL
# 3             AFE  2021  713090928                        0  SP.POP.TOTL
# 4             AFE  2020  694446100                        0  SP.POP.TOTL
#
#      indicator.value country.id                country.value
# 0  Population, total         ZH  Africa Eastern and Southern
# 1  Population, total         ZH  Africa Eastern and Southern
# 2  Population, total         ZH  Africa Eastern and Southern
# 3  Population, total         ZH  Africa Eastern and Southern
# 4  Population, total         ZH  Africa Eastern and Southern

# %% [markdown]
# ### Pagination
#
# You'll probably want to create DataFrames for each page, then "concatenate" them. Here's a structure you can start with:

# %%
# in a loop
#     get the first/next page of data
#     combine with the data that's already been retrieved
#     if there are fewer than the default number of records returned, stop the loop

# %%
total_pages = response.json()[0]["pages"]
total_pages
# Out:
# 346

# %%
for i in range(2, total_pages + 1):
    print("Prtocessing page ", i)
    url = (
        "https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page="
        + str(i)
    )
    response = requests.get(url)
    df_next = pd.json_normalize(response.json()[1])
    df = pd.concat([df, df_next], ignore_index=True)

df.info()
# Out:
# Prtocessing page  2
# Prtocessing page  3
# Prtocessing page  4
# Prtocessing page  5
# Prtocessing page  6
# Prtocessing page  7
# Prtocessing page  8
# Prtocessing page  9
# Prtocessing page  10
# Prtocessing page  11
# Prtocessing page  12
# Prtocessing page  13
# Prtocessing page  14
# Prtocessing page  15
# Prtocessing page  16
# Prtocessing page  17
# Prtocessing page  18
# Prtocessing page  19
# Prtocessing page  20
# Prtocessing page  21
# Prtocessing page  22
# Prtocessing page  23
# Prtocessing page  24
# Prtocessing page  25
# Prtocessing page  26
# Prtocessing page  27
# Prtocessing page  28
# Prtocessing page  29
# Prtocessing page  30
# Prtocessing page  31
# Prtocessing page  32
# Prtocessing page  33
# Prtocessing page  34
# Prtocessing page  35
# Prtocessing page  36
# Prtocessing page  37
# Prtocessing page  38
# Prtocessing page  39
# Prtocessing page  40
# Prtocessing page  41
# Prtocessing page  42
# Prtocessing page  43
# Prtocessing page  44
# Prtocessing page  45
# Prtocessing page  46
# Prtocessing page  47
# Prtocessing page  48
# Prtocessing page  49
# Prtocessing page  50
# Prtocessing page  51
# Prtocessing page  52
# Prtocessing page  53
# Prtocessing page  54
# Prtocessing page  55
# Prtocessing page  56
# Prtocessing page  57
# Prtocessing page  58
# Prtocessing page  59
# Prtocessing page  60
# Prtocessing page  61
# Prtocessing page  62
# Prtocessing page  63
# Prtocessing page  64
# Prtocessing page  65
# Prtocessing page  66
# Prtocessing page  67
# Prtocessing page  68
# Prtocessing page  69
# Prtocessing page  70
# Prtocessing page  71
# Prtocessing page  72
# Prtocessing page  73
# Prtocessing page  74
# Prtocessing page  75
# Prtocessing page  76
# Prtocessing page  77
# Prtocessing page  78
# Prtocessing page  79
# Prtocessing page  80
# Prtocessing page  81
# Prtocessing page  82
# Prtocessing page  83
# Prtocessing page  84
# Prtocessing page  85
# Prtocessing page  86
# Prtocessing page  87
# Prtocessing page  88
# Prtocessing page  89
# Prtocessing page  90
# Prtocessing page  91
# Prtocessing page  92
# Prtocessing page  93
# Prtocessing page  94
# Prtocessing page  95
# Prtocessing page  96
# Prtocessing page  97
# Prtocessing page  98
# Prtocessing page  99
# Prtocessing page  100
# Prtocessing page  101
# Prtocessing page  102
# Prtocessing page  103
# Prtocessing page  104
# Prtocessing page  105
# Prtocessing page  106
# Prtocessing page  107
# Prtocessing page  108
# Prtocessing page  109
# Prtocessing page  110
# Prtocessing page  111
# Prtocessing page  112
# Prtocessing page  113
# Prtocessing page  114
# Prtocessing page  115
# Prtocessing page  116
# Prtocessing page  117
# Prtocessing page  118
# Prtocessing page  119
# Prtocessing page  120
# Prtocessing page  121
# Prtocessing page  122
# Prtocessing page  123
# Prtocessing page  124
# Prtocessing page  125
# Prtocessing page  126
# Prtocessing page  127
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\adith\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File c:\Users\adith\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[34], line 4
#       2 print("Prtocessing page ", i)
#       3 url = "https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&page="+ str(i)
# ----> 4 response = requests.get(url)
#       5 df_next = pd.json_normalize(response.json()[1])
#       6 df = pd.concat([df, df_next], ignore_index=True)
#
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\adith\anaconda3\Lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ---
#
# [Submit.](https://computing-in-context.afeld.me/notebooks.html#submission)

# %% [markdown]
# Data link:
